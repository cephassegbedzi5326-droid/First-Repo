# %% [markdown]
# <a href="https://colab.research.google.com/github/cephassegbedzi5326-droid/First-Repo/blob/main/Question%201.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("cephas")
# Out:
# cephas

# %%
name ="cephas"
location ="Ashaiman"
Hometown ="Dodowa"
Favorite ="fried yam"
print(f"my name is {name} ")
# Out:
# my name is cephas

# %%
data_bloom =['Isaac', 'sibyl']
print(data_bloom)
# Out:
# ['Isaac', 'sibyl']

# %%
data_bloom.append ('paddy')

# %%
genz_dictionary ={
    "rizz":"to chat up a lady/guy",
    "no cap":"not telling lies",
    "Lit":"something fun"
}

# %%
shopping_items ={
"fruits":23,
"vegetables":45,
"spices":26
}

# %%
shopping_items
# Out:
# {'fruits': 23, 'vegetables': 45, 'spices': 26}

# %%
genz_dictionary.update({"It's giving":"something very good"})

# %%
print("Hello, world")
# Out:
# Hello, world

# %%
name="Segbedzi Cephas"
age=19
favorite_food ="jollof rice"
favorite_color="light yellow"
favorite_movie="tom and Jerry"
course="Data analytics"

# %%
print(favorite_food)
# Out:
# jollof rice

# %%
fruits=["apple","banana","pineapple","pawpaw","watermelon"]

# %%
fruits.append("grape")

# %%
print (fruits[0])
# Out:
# apple

# %%
print (fruits)
# Out:
# ['apple', 'banana', 'pineapple', 'pawpaw', 'watermelon']

# %%
President ={
    "name":"Mahama",
    "Party":"NDC",
    "age":76,
    "residence":"Jubilee house"
}

# %%
# Items and their prices
Items_prices={
    "Bread":"25",
    "Milk":"18",
    "Eggs":"2.5",
    "Sugar":"20"
    }

# %%
quantities={}

# %%
# ask the user for the quantity of items to buy
for item in Items_prices:
    amount = int(input(f"how many {item} do you want to buy"))
    quantities[item] = amount
# Out:
# how many Bread do you want to buy2
# how many Milk do you want to buy1
# how many Eggs do you want to buy6
# how many Sugar do you want to buy0

# %%
# calculating the total cost
Total_cost=0
for item in Items_prices:
    price=float(Items_prices[item]) # Convert price to float
    qty=quantities[item]
    Total_cost += price * qty
    print(f"\nInitial total cost:{Total_cost}GHs")
# Out:
# Initial total cost:50.0GHs
#
# Initial total cost:68.0GHs
#
# Initial total cost:83.0GHs
#
# Initial total cost:83.0GHs

# %%
if Total_cost >100:
  discount=Total_cost *0.1
  total_cost=Total_cost-discount
  print(f"\nTotal cost after discount:{total_cost}GHs")
else:
  print(f"No discount applied.")
# Out:
# No discount applied.

# %%
# calculating subtotal
subtotal=0
for item in Items_prices:
    price=float(Items_prices[item])
    qty=quantities[item]
    subtotal += price * qty

# %%
# calculating discount on the subtotal
discount=0
if subtotal >100:
   discount=subtotal*0.1

# %%
#calculating total
total=subtotal-discount

# %%
# printing the receipt
print("\n-----Receipt-----")
for item in Items_prices:
    Item_total=float(Items_prices[item]) * quantities[item]
    print(f"{item}(x{quantities[item]}):GHS {Item_total:.2f}")
    print("-------------")
    print(f"Subtotal : GHS {subtotal:.2f}")
    print(f"Discount : GHS {discount:.2f}")
    print(f"Total : GHS {total:.2f}")
# Out:
# -----Receipt-----
# Bread(x2):GHS 50.00
# -------------
# Subtotal : GHS 83.00
# Discount : GHS 0.00
# Total : GHS 83.00
# Milk(x1):GHS 18.00
# -------------
# Subtotal : GHS 83.00
# Discount : GHS 0.00
# Total : GHS 83.00
# Eggs(x6):GHS 15.00
# -------------
# Subtotal : GHS 83.00
# Discount : GHS 0.00
# Total : GHS 83.00
# Sugar(x0):GHS 0.00
# -------------
# Subtotal : GHS 83.00
# Discount : GHS 0.00
# Total : GHS 83.00
